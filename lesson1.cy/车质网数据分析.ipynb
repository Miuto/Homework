# %%
import pandas as pd
data = pd.read_csv('car_complain.csv')
data
# Out:
#          id  brand     car_model                   type  \
# 0    482028  一汽马自达           阿特兹       2020款 2.5L 蓝天运动版
# 1    482027   江淮汽车       江淮iEV6E            2017款 iEV6E
# 2    482026  一汽马自达           阿特兹       2020款 2.5L 蓝天运动版
# 3    482022  一汽-大众            迈腾   2009款 1.8TSI DSG 舒适型
# 4    482019   众泰汽车  众泰T600 Coupe      2017款 1.5T 自动 尊享型
# ..      ...    ...           ...                    ...
# 595  480802   北京现代            领动   2016款 1.6L 自动 智炫·精英型
# 596  480801  一汽-大众           高尔夫   2016款 1.4TSI 25周年纪念版
# 597  480799   吉利汽车            星越    2020款 350T 魅影骑士版AWD
# 598  480798   北京现代            悦纳  2016款 1.4L 手动 炫酷版 GLS
# 599  480795   东风日产            逍客     2016款 2.0L CVT 精英版
#
#                        desc              problem    datetime status
# 0       一汽马自达阿特兹B柱异响 车内异响严重             H93,H15,  2020-06-08   信息审核
# 1        江淮iEV6E动力电池故障 无法充电                H343,  2020-06-08   信息审核
# 2         一汽马自达阿特兹车身异响 天窗异响         H93,H15,H89,  2020-06-08   信息审核
# ...

# %%
result=data.groupby('brand')['car_model'].agg(投诉次数='count',投诉车型='nunique')
result
# Out:
#          投诉次数  投诉车型
# brand
# 一汽-大众      52     6
# 一汽-大众奥迪    19     6
# 一汽丰田       12     6
# 一汽吉林        2     2
# 一汽大众        6     1
# ...       ...   ...
# 长安汽车        6     5
# 长安铃木        2     2
# 长安马自达       4     2
# 雷克萨斯        2     2
# 领克汽车        5     2
#
# [75 rows x 2 columns]

# %%
result['平均值']=result['投诉次数']/result['投诉车型']
result
# Out:
#          投诉次数  投诉车型       平均值
# brand
# 一汽-大众      52     6  8.666667
# 一汽-大众奥迪    19     6  3.166667
# 一汽丰田       12     6  2.000000
# 一汽吉林        2     2  1.000000
# 一汽大众        6     1  6.000000
# ...       ...   ...       ...
# 长安汽车        6     5  1.200000
# 长安铃木        2     2  1.000000
# 长安马自达       4     2  2.000000
# 雷克萨斯        2     2  1.000000
# 领克汽车        5     2  2.500000
#
# [75 rows x 3 columns]

# %%
row=result.loc[result['平均值']==result['平均值'].max()]
row
# Out:
#        投诉次数  投诉车型   平均值
# brand
# 一汽马自达    95     2  47.5

# %%
new_names = ['problem_' + str(x + 1) for x in range(4)]
new_data=pd.concat([data, data['problem'].str.split(',', expand=True)], axis=1,names=new_names)
new_data
#不知道怎么删除所有值均问None的列
# Out:
#          id  brand     car_model                   type  \
# 0    482028  一汽马自达           阿特兹       2020款 2.5L 蓝天运动版
# 1    482027   江淮汽车       江淮iEV6E            2017款 iEV6E
# 2    482026  一汽马自达           阿特兹       2020款 2.5L 蓝天运动版
# 3    482022  一汽-大众            迈腾   2009款 1.8TSI DSG 舒适型
# 4    482019   众泰汽车  众泰T600 Coupe      2017款 1.5T 自动 尊享型
# ..      ...    ...           ...                    ...
# 595  480802   北京现代            领动   2016款 1.6L 自动 智炫·精英型
# 596  480801  一汽-大众           高尔夫   2016款 1.4TSI 25周年纪念版
# 597  480799   吉利汽车            星越    2020款 350T 魅影骑士版AWD
# 598  480798   北京现代            悦纳  2016款 1.4L 手动 炫酷版 GLS
# 599  480795   东风日产            逍客     2016款 2.0L CVT 精英版
#
#                        desc              problem    datetime status     0  \
# 0       一汽马自达阿特兹B柱异响 车内异响严重             H93,H15,  2020-06-08   信息审核   H93
# 1        江淮iEV6E动力电池故障 无法充电                H343,  2020-06-08   信息审核  H343
# ...
